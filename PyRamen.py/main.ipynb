# %%
from pathlib import Path
import csv


menu_filepath = Path(r'C:\Users\Ldkel\OneDrive\Desktop\FinTech\Homework\python-homework\PyRamen.py\menu_data.csv')
sales_filepath = Path(r'C:\Users\Ldkel\OneDrive\Desktop\FinTech\Homework\python-homework\PyRamen.py\sales_data.csv')

menu = []
sales = []
report = {}
row_count = 0
quantity = []
menu_item = []


with open(menu_filepath, "r") as csvfile: 
    
    csv_reader = csv.reader(csvfile, delimiter = ",")
    header = next(csv_reader)
    
    for row in csv_reader:
        menu.append(row)

with open(sales_filepath, "r") as csvfile:
    
    csv_reader = csv.reader(csvfile, delimiter = ",")
    header = next(csv_reader)
          
    for row in csv_reader:
        sales.append(row)
    
    

for sales_row in sales: 
    
    sales_item = sales_row[4]
    quantity = sales_row[3]
    
    if sales_item not in report:
        report[sales_item] = {
            "01-count": 0,
            "02-revenue": 0,
            "03-cogs": 0,
            "04-profit": 0}
    else:
        continue       

for sales_row in sales: 
    
    sales_item = sales_row[4]
    quantity = sales_row[3]
    
    if sales_item in report:
        report[sales_item]["01-count"] += int(quantity)              

for sales_row in sales:
    
    sales_item = sales_row[4]
    quantity = sales_row[3]
    
    for menu_row in menu:
        menu_item = menu_row[0]
        menu_price = menu_row[3]
        menu_cost = menu_row[4]
        
        if sales_item == menu_item:
            report[menu_item]["02-revenue"] += (int(menu_price) * int(quantity))
            report[menu_item]["03-cogs"] += (int(menu_cost) * int(quantity))
        else:
            print(f"{sales_item} does not equal {item}! NO MATCH!")
            continue
            

for item, valuedict in report.items():
    
    for key in valuedict:
        
        revenue = report[item]["02-revenue"]
        cogs = report[item]["03-cogs"]
        
        if key == "04-profit":
            report[item][key] = revenue - cogs
        else:
            continue

output_path = Path("PyRamen.txt")

with open(output_path, 'w') as file:
    file.write("Financial Report \n")
    
    for key in report:
        file.write(f"{key} {report[key]} \n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5860/3568520757.py in <module>
#      68             report[menu_item]["03-cogs"] += (int(menu_cost) * int(quantity))
#      69         else:
# ---> 70             print(f"{sales_item} does not equal {item}! NO MATCH!")
#      71             continue
#      72
#
# NameError: name 'item' is not defined
